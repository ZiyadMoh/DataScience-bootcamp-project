# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df2 = pd.read_csv('https://objectstorage.me-jeddah-1.oraclecloud.com/p/sWT5fKMYCFddg548Fdv--DqoIbakW-dIAm1V8BYQ_W02N-drlA7AutmokhoKTTY6/n/axotfeyop1iu/b/bucket-20211126-1509/o/dataset2data.csv')
df = pd.read_csv('https://objectstorage.me-jeddah-1.oraclecloud.com/p/dtHEcsOQVxXPWk0MA-g0tuU6nICt48twwBjd_wTVKnaOHC9I_bxxHdYeEV5sWL3U/n/axotfeyop1iu/b/bucket-20211126-1509/o/projectDatasetgenres_v2.csv')

# %%
df

# %%
sns.pairplot(df, hue='genre');

# %%
df.head()

# %%
df2.info()

# %%
df.info()

# %%
_df = df.drop(['id', 'uri', ''])

# %%
import spotipy
import requests as rq

url = 'https://api.spotify.com'

# %%
url = 'https://api.spotify.com'
songID = '0vSWgAlfpye0WCGeNmuNhy'
conUrl = url+'/tracks/'+songID
song = rq.get('https://api.spotify.com/spotify:track:6rqhFgbbKwnb9MLmUQDhG6')
song

# %%
import spotipy.oauth2 as oauth2
from spotipy.oauth2 import SpotifyOAuth
from spotipy.oauth2 import SpotifyClientCredentials

# %%
auth_manager = SpotifyClientCredentials(client_id = '41036c440e754b3ead97645e50bb4b42', client_secret = '2a188920e515470d81c44ea127c5980a')

# %%
sadoonURI = 'spotify:playlist:spotify:playlist:0O6BKF6Uul69FYaqF5MApV'
sadoon = sp.playlist(sadoonURI)
sadoon.get('tracks', {}).get('')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4072/2129752739.py in <module>
#       1 sadoonURI = 'spotify:playlist:spotify:playlist:0O6BKF6Uul69FYaqF5MApV'
# ----> 2 sadoon = sp.playlist(sadoonURI)
#       3 sadoon.get('tracks', {}).get('')
#
# AttributeError: module 'spotipy' has no attribute 'playlist'

# %%
print(sadoon['tracks'])

# %%
type(sadoon)

# %%
D = {'emp1': {'name': 'Bob', 'job': 'Mgr'},
     'emp2': {'name': 'Kim', 'job': 'Dev'},
     'emp3': {'name': 'Sam', 'job': 'Dev'}}


for id, info in D.items():
    print("\nEmployee ID:", id)
    for key in info:
        print(key + ':', info[key])

# Prints Employee ID: emp1
#        name: Bob
#        job: Mgr

#        Employee ID: emp2
#        name: Kim
#        job: Dev

#        Employee ID: emp3
#        name: Sam
#        job: Dev

# %%
for track in items:
    track[]

# %%
print(items)

# %%
items_df = pd.DataFrame(sadoon)
items_df

# %%
tracks = []
items = sadoon['tracks'].get('items')
items

# %%
for x in items[0]['track']:
    print(x)

# %%
playListUri = 'spotify:playlist:0FWMLfkIKVzEHut8sJnUPZ'
test = sp.playlist(playListUri)
test
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4072/1588163809.py in <module>
#       1 playListUri = 'spotify:playlist:0FWMLfkIKVzEHut8sJnUPZ'
# ----> 2 test = sp.playlist(playListUri)
#       3 test
#
# AttributeError: module 'spotipy' has no attribute 'playlist'

# %%
test.keys()

# %%
tracks = test.get('tracks')
tracks

# %%
items = tracks.get('items')
type(items)

# %%
track_list = []
for x in items:
    track_list.append(x.get('track'))

# %%
track_list

# %%
Uris = []
for t in track_list:
    Uris.append(t.get('uri'))
Uris

# %%
data = []
for u in Uris:
    sp.audi

# %%
tracks = np.array(tracks)
tracks

# %%
sp = spotipy.Spotify(auth_manager=auth_manager)
artist_info = 'spotify:artist:0epOFNiUfyON9EYx7Tpr6V'
the_strokes = sp.artist(artist_info)

the_strokes
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/0epOFNiUfyON9EYx7Tpr6V'},
#  'followers': {'href': None, 'total': 4059703},
#  'genres': ['alternative rock',
#   'garage rock',
#   'modern rock',
#   'permanent wave',
#   'rock'],
#  'href': 'https://api.spotify.com/v1/artists/0epOFNiUfyON9EYx7Tpr6V',
#  'id': '0epOFNiUfyON9EYx7Tpr6V',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb64d74f5985cb66b2f7b60e93',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab6761610000517464d74f5985cb66b2f7b60e93',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f17864d74f5985cb66b2f7b60e93',
#    'width': 160}],
#  'name': 'The Strokes',
#  'popularity': 78,
#  'type': 'artist',
#  'uri': 'spotify:artist:0epOFNiUfyON9EYx7Tpr6V'}

# %%
ana = 'spotify:track:44AtPowvdYbDMz6VaBBO3u'
anas = sp.audio_analysis(ana)
anas

# %%
MyTopSongs2021 = getUris('spotify:playlist:37i9dQZF1DXaMu9xyX1HzK')
MyTopSongs2021

# %%
len(MyTopSongs2021)

# %%
# Get the tracks uri for any list on spotify and put them into Data Frame
def getDataFrame(playlistUri):
    offset = 0
    limit_step = 100
    _list = []
    df = pd.DataFrame()
    
    #item = sp.playlist_tracks(playlistUri, fields='items.track.uri')
    
    for offset in range(0, 10500, limit_step):
        #print(offset)
        temp = sp.playlist_tracks(playlistUri, fields='items.track.uri', offset=offset)
        try:
            #print(temp.get('items')) #working
            if len(temp.get('items')) == 0:
                break
            #print(temp) 
            items = temp.get('items')
            #print(len(items)) working
            for i in items:
                temp2 = i.get('track')
                if(len(temp2) > 1):
                    break
                _list = (temp2.get('uri'))
                data = sp.audio_features(_list)
                df = df.append(data, ignore_index=True)
        except:
            print(print(offset))
            continue
    return df

# %%
topsongsofalltime429 = getDataFrame('spotify:playlist:0iGFTMr16dxi4LX68pue6o')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4072/4244066428.py in <module>
# ----> 1 topsongsofalltime429 = getDataFrame('spotify:playlist:0iGFTMr16dxi4LX68pue6o')
#
# ~\AppData\Local\Temp/ipykernel_4072/2928276449.py in getDataFrame(playlistUri)
#      10     for offset in range(0, 10500, limit_step):
#      11         #print(offset)
# ---> 12         temp = sp.playlist_tracks(playlistUri, fields='items.track.uri', offset=offset)
#      13         print(len(temp.get('items'))) #working
#      14         if len(temp.get('items')) == 0:
#
# AttributeError: module 'spotipy' has no attribute 'playlist_tracks'

# %%
topsongsofalltime429.duplicated().count()

# %%
testdf = pd.DataFrame()

# %%
daa = pd.DataFrame()

# %%
playlists = ['', '', '', '', '', '', '', '', '', '',
            '', '', '', '', '', '', '', '', '', '',
             '', '', '', '', '', '', '', '', '', '',
             '', '', '', '', '', '', '', '', '', '',
             '', '', '', '', '', '', '', '', '', '',
             '', '', '', '', '', '', '', '', '', '',
             '', '', '', '', '', '', '', '', '', '',
             '', '', '', '', '', '', '', '', '', '',
             '', '', '', '', '', '', '', '', '', '',
             '', '', '', '', '', '', '', '', '', '',
             '', '', '', '', '', '', '', '', '', '',
             '', '', '', '', '', '', '', '', '', '',
            ]

# %%
TopKhaligySongs = getDataFrame('spotify:playlist:37i9dQZF1DWU486KSiznWZ')
TopKhaligySongs

# %%
Top100GSOAT = getDataFrame('spotify:playlist:6i2Qd6OpeRBAzxfscNXeWp')
Top100GSOAT

# %%
p = sp.playlist_tracks('spotify:playlist:0iGFTMr16dxi4LX68pue6o', fields='items.track.uri')
p = p.get('items')
type(p)

# %%
tenthousand = getDataFrame('spotify:playlist:1G8IpkZKobrIlXcVPoSIuf')
# Out:
# 400
# None

# %%
tenthousand
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.482   0.721    0    -6.839     1       0.0321      0.731000
# 1            0.485   0.863    1    -9.027     1       0.0495      0.000012
# 2            0.364   0.457    4   -14.162     0       0.0675      0.290000
# 3            0.398   0.413    1   -10.934     1       0.0388      0.082200
# 4            0.518   0.756   10   -10.851     1       0.0915      0.735000
# ...            ...     ...  ...       ...   ...          ...           ...
# 8068         0.332   0.707    7   -12.698     1       0.0361      0.000012
# 8069         0.464   0.749    6    -8.564     1       0.4800      0.224000
# 8070         0.694   0.710    2    -9.793     1       0.3400      0.527000
# 8071         0.332   0.800    1    -9.746     1       0.0326      0.000368
# 8072         0.499   0.763    7   -11.617     1       0.0704      0.244000
#
# ...

# %%
t = get_all_saved_tracks
t

# %%
len(Top100GSOAT)

# %%
len(TopSongsOfAllTime)

# %%
TopSongsOfAllTime = getDataFrame('spotify:playlist:0iGFTMr16dxi4LX68pue6o')

# %%
TopSongsOfAllTime = getDataFrame('spotify:playlist:0iGFTMr16dxi4LX68pue6o')
TopSongsOfAllTime

# %%
pla1 = getUris('spotify:playlist:4CA0aYw8dKvrJJKneAwUOy')
pla1

# %%
arra = arra[58:]

# %%
len(arra)

# %%
pla1Ft = sp.audio_features(pla1)
pla1Ft

# %%
FIT = 'spotify:playlist:4CA0aYw8dKvrJJKneAwUOy'
FLTDURIs = sp.playlist_tracks(FIT, fields='items.track.uri') # get playlist tracks uri

# %%
type(FLTDURIs)

# %%
te = FLTDURIs.get('items')
len(te)

# %%
list1 = []
for i in te:
    list1.append((i.get('track')))
list1.

# %%
uris =[]
for u in list1:
    print(type(u))
    uris.append(u.get('uri'))

# %%
uris

# %%
data = sp.audio_features(uris)
data

# %%
df = pd.DataFrame(data)
df.info()

# %%
df.head()

# %%
FLTD

# %%
FLTD = FLTD.get('itmes')

# %%
FLTD['items'].keys()

# %%
the_strokes_df = pd.read_csv(the_strokes)
the_strokes_df

# %% [markdown]
# ## Visulization

# %%
import networkx as nx
from scipy import spatial


dict_edges = {}
for i in range(len(list_songs)):
    list_val = []
    for j in range(i):
        a_row = list(sorted_df_1.iloc[j])
        list_val.append([j, 1 - spatial.distance.cosine(sorted_df_1.iloc[i], a_row),list(sorted_df.iloc[j])[1] ])
    for j in range(i+1,len(list_songs)):    
        a_row = list(sorted_df_1.iloc[j])
        list_val.append([j, 1 - spatial.distance.cosine(sorted_df_1.iloc[i], a_row), list(sorted_df.iloc[j])[1]])
    dict_edges[i] = list_val 
    

new_dict = {}
for i in range(100):
    list_to_put = []
    for j in range(len(dict_edges[i])):
        if dict_edges[i][j][1] >= 0.95:
            list_to_put.append(dict_edges[i][j])      
    new_dict[i] = list_to_put
    
    
G = nx.Graph()
for i in range(100):
    for j in range(len(new_dict[i])):
        G.add_node(i,label = i)
        G.add_edge(i, new_dict[i][j][0], weight=new_dict[i][j][1], title = new_dict[i][j][2])

# %%
max_deg = 0
node = 0
for n in G.nodes():
    if G.degree[n] > max_deg:
        max_deg = G.degree[n]
        node = n
print(max_deg, node) # highest song

# %% [markdown]
# ## Getting Dataset

# %%
df = pd.DataFrame()

# %%
dataset = ['spotify:playlist:0iGFTMr16dxi4LX68pue6o', 'spotify:playlist:1yMlpNGEpIVUIilZlrbdS0',
           'spotify:playlist:2T5I8nhtRvYaYJpToPEUXg', 'spotify:playlist:3PP4DLeNOFKlK0QwI5P7rf',
           'spotify:playlist:2cipIdxrOhiJzOTwmEQJoI', 'spotify:playlist:37i9dQZF1DWZBCPUIUs2iR',
          'spotify:playlist:3vLOUuQlW3hZwH0z69QdX2', 'spotify:playlist:3vDe8D64ytZRKXt0AsJT0B',
           'spotify:playlist:5Udnh472z0CeexGPSpdIw9', 'spotify:playlist:43G7MrbiiExfKMFrZhaEjQ',
           'spotify:playlist:2evbAvr0FkJ6a6KwQi5AIN', 'spotify:playlist:0cWBAJCMCb7bYmocJF4g6q',
           'spotify:playlist:1JQ26E2gd6jnbyNnTz7m74', 'spotify:playlist:3hMuAfaMcg9dWAwNTTuvXR'
          ]

# %%
more_music = ['spotify:playlist:2sm4Ivn2GHgE92AGxzn6Pr', 'spotify:playlist:3Pgs1JgS7iS1YyVtVbVBZV',
              'spotify:playlist:4dYHpHMfbhfgHOIipjpnS4', 'spotify:playlist:4Lxnjq63E87MUVIqkgHEWF',
              'spotify:playlist:10u0sjvu9VJy2ZpqiIYwP0', 'spotify:playlist:0M72pFlwTDllXaD9d54TVg',
              'spotify:playlist:3rfy4WG3wn8yUkfL3NJR9t', 'spotify:playlist:7xmzLaGblotXY1ccVqD9as'
             ]

# %%
df2 = pd.DataFrame()

# %%
c = 0
for s in more_music:
    print(c)
    c += 1
    df2= df2.append(getDataFrame(h))
df2
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.417   0.973    5    -3.746     1       0.1030      0.000177
# 1           0.362   0.984    2    -3.632     1       0.0616      0.000009
# 2           0.472   0.880    9    -4.925     1       0.0519      0.025700
# 3           0.316   0.903    3    -3.234     1       0.0908      0.000331
# 4           0.349   0.786    9    -4.771     1       0.0351      0.006580
# ..            ...     ...  ...       ...   ...          ...           ...
# 495         0.528   0.974    9    -3.309     0       0.0486      0.019800
# 496         0.581   0.924    6    -4.348     0       0.0854      0.004430
# 497         0.152   0.975    7    -3.072     0       0.2600      0.058300
# 498         0.529   0.930    0    -4.161     0       0.0448      0.003200
# 499         0.550   0.881    0    -5.452     0       0.0941      0.006680
#
# ...

# %%
url = df2.iloc[1]
url
# Out:
# danceability                                                    0.362
# energy                                                          0.984
# key                                                                 2
# loudness                                                       -3.632
# mode                                                                1
# speechiness                                                    0.0616
# acousticness                                                 0.000009
# instrumentalness                                             0.000002
# liveness                                                        0.315
# valence                                                         0.413
# tempo                                                         181.024
# type                                                   audio_features
# id                                             0Fg27KIHRVGjZFjLIZEBjZ
# ...

# %%
df = df.append(tenthousand)
df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.794   0.711    8    -5.124     0       0.0699      0.300000
# 1            0.530   0.422    5    -6.262     1       0.0342      0.407000
# 2            0.743   0.807    1    -3.780     1       0.0364      0.043500
# 3            0.818   0.799    1    -4.100     0       0.1560      0.001070
# 4            0.600   0.663    3    -5.802     1       0.0477      0.225000
# ...            ...     ...  ...       ...   ...          ...           ...
# 8068         0.332   0.707    7   -12.698     1       0.0361      0.000012
# 8069         0.464   0.749    6    -8.564     1       0.4800      0.224000
# 8070         0.694   0.710    2    -9.793     1       0.3400      0.527000
# 8071         0.332   0.800    1    -9.746     1       0.0326      0.000368
# 8072         0.499   0.763    7   -11.617     1       0.0704      0.244000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12790 entries, 0 to 8072
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      12790 non-null  float64
#  1   energy            12790 non-null  float64
#  2   key               12790 non-null  int64
#  3   loudness          12790 non-null  float64
#  4   mode              12790 non-null  int64
#  5   speechiness       12790 non-null  float64
#  6   acousticness      12790 non-null  float64
#  7   instrumentalness  12790 non-null  float64
#  8   liveness          12790 non-null  float64
#  9   valence           12790 non-null  float64
#  10  tempo             12790 non-null  float64
#  11  type              12790 non-null  object
#  12  id                12790 non-null  object
#  13  uri               12790 non-null  object
#  14  track_href        12790 non-null  object
#  15  analysis_url      12790 non-null  object
# ...

# %%
df.duplicated().sum()
# Out:
# 271

# %%
df.drop_duplicates(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12519 entries, 0 to 8072
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      12519 non-null  float64
#  1   energy            12519 non-null  float64
#  2   key               12519 non-null  int64
#  3   loudness          12519 non-null  float64
#  4   mode              12519 non-null  int64
#  5   speechiness       12519 non-null  float64
#  6   acousticness      12519 non-null  float64
#  7   instrumentalness  12519 non-null  float64
#  8   liveness          12519 non-null  float64
#  9   valence           12519 non-null  float64
#  10  tempo             12519 non-null  float64
#  11  type              12519 non-null  object
#  12  id                12519 non-null  object
#  13  uri               12519 non-null  object
#  14  track_href        12519 non-null  object
#  15  analysis_url      12519 non-null  object
# ...

# %%
df.to_csv('myDataset') #saving the dataset

# %%
df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.794   0.711    8    -5.124     0       0.0699      0.300000
# 1            0.530   0.422    5    -6.262     1       0.0342      0.407000
# 2            0.743   0.807    1    -3.780     1       0.0364      0.043500
# 3            0.818   0.799    1    -4.100     0       0.1560      0.001070
# 4            0.600   0.663    3    -5.802     1       0.0477      0.225000
# ...            ...     ...  ...       ...   ...          ...           ...
# 8068         0.332   0.707    7   -12.698     1       0.0361      0.000012
# 8069         0.464   0.749    6    -8.564     1       0.4800      0.224000
# 8070         0.694   0.710    2    -9.793     1       0.3400      0.527000
# 8071         0.332   0.800    1    -9.746     1       0.0326      0.000368
# 8072         0.499   0.763    7   -11.617     1       0.0704      0.244000
#
# ...

# %%
song = df.iloc[5000]
song
# Out:
# danceability                                                    0.647
# energy                                                          0.762
# key                                                                 2
# loudness                                                       -5.856
# mode                                                                1
# speechiness                                                    0.0287
# acousticness                                                   0.0599
# instrumentalness                                             0.000003
# liveness                                                       0.0705
# valence                                                          0.93
# tempo                                                          89.837
# type                                                   audio_features
# id                                             6NxsCnLeLd8Ai1TrgGxzIx
# ...

# %%
sa=sp.audio_analysis('6NxsCnLeLd8Ai1TrgGxzIx')

# %%
df.lables()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4072/2911821227.py in <module>
# ----> 1 df.lables()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'lables'

# %%
a = input()
print(a)
# Out:
# https://open.spotify.com/track/0htLu08TAzKUzPg3zeZPn1?si=fdee9a4b95b04335
# https://open.spotify.com/track/0htLu08TAzKUzPg3zeZPn1?si=fdee9a4b95b04335

# %%
t4 = ('https://open.spotify.com/track/0htLu08TAzKUzPg3zeZPn1?si=fdee9a4b95b04335')

# %%
spotify:track:0htLu08TAzKUzPg3zeZPn1

# %%
import re

# %%
t4 = sp.track('https://open.spotify.com/track/0htLu08TAzKUzPg3zeZPn1?si=fdee9a4b95b04335')

# %% [markdown]
# Get URI function

# %%
def getURI(url):
    uri = (sp.track(url)).get('uri')
    return uri

# %%
input1 = input() #testing 
output = getURI(input1)
output
# Out:
# https://open.spotify.com/track/0FeKXParpIZgzNzzOeJiZY?si=a6fa4cf3119d4730
# 'spotify:track:0FeKXParpIZgzNzzOeJiZY'

# %%
def getURL(uri):
    url =

# %%
df.head(1)
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.794   0.711    8    -5.124     0       0.0699           0.3
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0               0.0    0.0955    0.955  174.915  audio_features
#
#                        id                                   uri  \
# 0  1ExfPZEiahqhLyajhybFeS  spotify:track:1ExfPZEiahqhLyajhybFeS
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1ExfPZEiahqh...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/1Exf...       189109
#
#    time_signature
# 0               4

# %%
sp.recommendations(listOfTracks)

# %%
df3 = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-01-21/spotify_songs.csv')
df3
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
df.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature'],
#       dtype='object')

# %%
URIdf = df['uri']

# %% [markdown]
# ## Data Cleaning

# %%
non_numeric_df = df.uri
non_numeric_df
# Out:
# 0       spotify:track:1ExfPZEiahqhLyajhybFeS
# 1       spotify:track:2vwlzO0Qp8kfEtzTsCXfyE
# 2       spotify:track:3tCwjWLicbjsMCvXhN0WOE
# 3       spotify:track:67awxiNHNyjMXhVgsHuIrs
# 4       spotify:track:4nVBt6MZDDP6tRVdQTgxJg
#                         ...
# 8068    spotify:track:2QSD3K3b3BJ8DPhGhQfDPW
# 8069    spotify:track:49XnDVsYOHgV4gFZeCojKj
# 8070    spotify:track:5Y9IIH8Xmo1nuk0gfFjc4Q
# 8071    spotify:track:0ya0JYEFoXNviB8RMeHDtW
# 8072    spotify:track:32y1kRg6IF3f6jpkHxzFoK
# Name: uri, Length: 12519, dtype: object

# %%
df.drop(columns=['type', 'id', 'uri', 'track_href', 'analysis_url'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12519 entries, 0 to 8072
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      12519 non-null  float64
#  1   energy            12519 non-null  float64
#  2   key               12519 non-null  int64
#  3   loudness          12519 non-null  float64
#  4   mode              12519 non-null  int64
#  5   speechiness       12519 non-null  float64
#  6   acousticness      12519 non-null  float64
#  7   instrumentalness  12519 non-null  float64
#  8   liveness          12519 non-null  float64
#  9   valence           12519 non-null  float64
#  10  tempo             12519 non-null  float64
#  11  duration_ms       12519 non-null  int64
#  12  time_signature    12519 non-null  int64
# dtypes: float64(9), int64(4)
# memory usage: 1.6 MB

# %%
df.corr()
# Out:
#                   danceability    energy       key  loudness      mode  \
# danceability          1.000000 -0.018681  0.018077  0.027002  0.012413
# energy               -0.018681  1.000000  0.021294  0.774448 -0.046020
# key                   0.018077  0.021294  1.000000  0.013417 -0.120804
# loudness              0.027002  0.774448  0.013417  1.000000 -0.033249
# mode                  0.012413 -0.046020 -0.120804 -0.033249  1.000000
# speechiness           0.164357  0.171365  0.031961  0.121061 -0.060449
# acousticness          0.000502 -0.711767 -0.036046 -0.553577  0.088388
# instrumentalness     -0.243325 -0.079858  0.002633 -0.210936 -0.062887
# liveness             -0.079679  0.158506 -0.008502  0.108819  0.011291
# valence               0.573496  0.135881  0.004314  0.064412  0.105472
# tempo                -0.136872  0.207839  0.003951  0.147467  0.021628
# duration_ms          -0.224665  0.094645  0.017848  0.024892 -0.095376
# ...
